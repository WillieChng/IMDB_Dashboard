# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from os import path, environ
from dotenv import load_dotenv
from flask_sqlalchemy import SQLAlchemy
from Website import models

# %%
#Load CSV file 
movies_df = pd.read_csv("IMDb_Dataset_Edited.csv")
movies_df.info()

# Replace NaN values with appropriate defaults
movies_df.fillna({
    'overview': '',
    'status': '',
    'release_year': 0,
    'popularity': 0.0,
    'vote_average': 0.0,
    'vote_count': 0,
    'adult': False,
    'overview_sentiment': 0.0,
    'all_combined_keywords': '',
    'Star1': '',
    'Star2': '',
    'Star3': '',
    'Star4': ''
}, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89538 entries, 0 to 89537
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       89538 non-null  int64
#  1   title                    89538 non-null  object
#  2   vote_average             89538 non-null  float64
#  3   vote_count               89538 non-null  int64
#  4   status                   89538 non-null  object
#  5   release_date             89538 non-null  object
#  6   revenue                  89538 non-null  int64
#  7   runtime                  89538 non-null  int64
#  8   adult                    89538 non-null  bool
#  9   budget                   89538 non-null  int64
#  10  imdb_id                  40169 non-null  object
#  11  original_language        89538 non-null  object
#  12  original_title           89538 non-null  object
#  13  overview                 85545 non-null  object
#  14  popularity               89538 non-null  float64
#  15  tagline                  21199 non-null  object
#  16  production_companies     39255 non-null  object
#  17  production_countries     43045 non-null  object
#  18  spoken_languages         45698 non-null  object
#  19  keywords                 89538 non-null  object
#  20  release_year             89538 non-null  int64
#  21  Director                 89538 non-null  object
#  22  AverageRating            1118 non-null   float64
#  23  Poster_Link              174 non-null    object
#  24  Certificate              2566 non-null   object
#  25  IMDB_Rating              2596 non-null   float64
#  26  Meta_score               145 non-null    float64
#  27  Star1                    2596 non-null   object
#  28  Star2                    174 non-null    object
#  29  Star3                    174 non-null    object
#  30  Star4                    174 non-null    object
#  31  Writer                   53758 non-null  object
#  32  Director_of_Photography  27886 non-null  object
#  33  Producers                35010 non-null  object
#  34  Music_Composer           12716 non-null  object
#  35  genres_list              89538 non-null  object
#  36  Cast_list                89538 non-null  object
#  37  overview_sentiment       89538 non-null  float64
#  38  all_combined_keywords    89538 non-null  object
# dtypes: bool(1), float64(6), int64(6), object(26)
# memory usage: 26.0+ MB

# %%
#Connect to Database
load_dotenv()
engine = create_engine(environ.get("DATABASE_URI"))
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# **Helper Functions**

# %%
# Clean and split data
def clean_and_split(data, delimiter=','):
    if pd.isna(data):
        return []
    return [item.strip() for item in data.replace('[', '').replace(']', '').replace("'", "").split(delimiter)]

# Insert unique Genres, Actors, and Directors
def insert_unique_records(session, model, names):
    unique_names = set(names)
    for name in unique_names:
        if name:  # Avoid inserting empty strings
            instance = model(name=name)
            session.add(instance)
    session.commit()

# %% [markdown]
# 1. Insert Genres and Actors (for deduplication)

# %%
# # Insert Genres
# unique_genres = set(genre.strip() for genres in movies_df['genres_list'] if pd.notna(genres) for genre in genres.replace('[', '').replace(']', '').replace("'", "").split(', '))
# for genre_name in unique_genres:
#     genre = models.Genre(name=genre_name.strip())
#     session.add(genre)
# session.commit()

# # Clean and insert Actors
# unique_actors = set(actor.strip() for cast_list in movies_df['Cast_list'] if pd.notna(cast_list) for actor in cast_list.replace('[', '').replace(']', '').replace("'", "").split(', '))
# for actor_name in unique_actors:
#     actor = models.Actor(name=actor_name.strip())
#     session.add(actor)
# session.commit()


# # Insert Directors
# unique_directors = set(director.strip() for directors in movies_df['Director'] if pd.notna(directors) for director in directors.split(','))
# for director_name in unique_directors:
#     director = models.Director(name=director_name)
#     session.add(director)
# session.commit()

# Prepare data for genres, actors, and directors
genres = [genre for genres in movies_df['genres_list'] for genre in clean_and_split(genres)]
actors = [actor for cast_list in movies_df['Cast_list'] for actor in clean_and_split(cast_list)]
directors = [director for director_list in movies_df['Director'] for director in clean_and_split(director_list)]

# Insert unique records for each model
insert_unique_records(session, models.Genre, genres)
insert_unique_records(session, models.Actor, actors)
insert_unique_records(session, models.Director, directors)

# After inserting unique genres, actors, and directors, the code retrieves all entries and creates dictionaries (genre_map, actor_map, director_map) 
# These dictionaries allow quick lookups for each genre, actor, or director without querying the database for each row to improve performance
genre_map = {g.name: g for g in session.query(models.Genre).all()}
actor_map = {a.name: a for a in session.query(models.Actor).all()}
director_map = {d.name: d for d in session.query(models.Director).all()}

# %% [markdown]
# 2. Insert Movies and link relationship

# %%
# Insert Movies and link relationships
for index, row in movies_df.iterrows():
    try:
        movie = models.Movie(
            title=row['title'],
            overview=row['overview'],
            status=row['status'],
            release_year=row['release_year'],
            popularity=row['popularity'],
            vote_average=row['vote_average'],
            vote_count=row['vote_count'],
            adult=row['adult'],
            overview_sentiment=row['overview_sentiment'],
            all_combined_keywords=row['all_combined_keywords'],
            Star1=row['Star1'],
            Star2=row['Star2'],
            Star3=row['Star3'],
            Star4=row['Star4']
        )
        session.add(movie)
        session.commit()

    #FOR ASSOCIATION RELATIONSHIP TABLES 
        # Link Genres
        for genre_name in clean_and_split(row['genres_list']):
            genre = genre_map.get(genre_name)
            if genre:
                movie.genres.append(genre)

        # Link Actors
        for actor_name in clean_and_split(row['Cast_list']):
            actor = actor_map.get(actor_name)
            if actor:
                movie.actors.append(actor)

        # Link Directors
        for director_name in clean_and_split(row['Director']):
            director = director_map.get(director_name)
            if director:
                movie.directors.append(director)
        
        session.bulk_save_objects(movie)
        session.commit()
        
    except Exception as e:
        session.rollback()
        print(f"Error processing row {index}: {e}")

# Close the session
session.close()
# Out:
# Error processing row 0: 'Movie' object is not iterable
# Error processing row 1: 'Movie' object is not iterable
# Error processing row 2: 'Movie' object is not iterable
# Error processing row 3: 'Movie' object is not iterable
# Error processing row 4: 'Movie' object is not iterable
# Error processing row 5: 'Movie' object is not iterable
# Error processing row 6: 'Movie' object is not iterable
# Error processing row 7: 'Movie' object is not iterable
# Error processing row 8: 'Movie' object is not iterable
# Error processing row 9: 'Movie' object is not iterable
# Error processing row 10: 'Movie' object is not iterable
# Error processing row 11: 'Movie' object is not iterable
# Error processing row 12: 'Movie' object is not iterable
# Error processing row 13: 'Movie' object is not iterable
# Error processing row 14: 'Movie' object is not iterable
# Error processing row 15: 'Movie' object is not iterable
# Error processing row 16: 'Movie' object is not iterable
# Error processing row 17: 'Movie' object is not iterable
# Error processing row 18: 'Movie' object is not iterable
# Error processing row 19: 'Movie' object is not iterable
# Error processing row 20: 'Movie' object is not iterable
# Error processing row 21: 'Movie' object is not iterable
# Error processing row 22: 'Movie' object is not iterable
# Error processing row 23: 'Movie' object is not iterable
# Error processing row 24: 'Movie' object is not iterable
# Error processing row 25: 'Movie' object is not iterable
# Error processing row 26: 'Movie' object is not iterable
# Error processing row 27: 'Movie' object is not iterable
# Error processing row 28: 'Movie' object is not iterable
# Error processing row 29: 'Movie' object is not iterable
# Error processing row 30: 'Movie' object is not iterable
# Error processing row 31: 'Movie' object is not iterable
# Error processing row 32: 'Movie' object is not iterable
# Error processing row 33: 'Movie' object is not iterable
# Error processing row 34: 'Movie' object is not iterable
# Error processing row 35: 'Movie' object is not iterable
# Error processing row 36: 'Movie' object is not iterable
# Error processing row 37: 'Movie' object is not iterable
# Error processing row 38: 'Movie' object is not iterable
# Error processing row 39: 'Movie' object is not iterable
# Error processing row 40: 'Movie' object is not iterable
# Error processing row 41: 'Movie' object is not iterable
# Error processing row 42: 'Movie' object is not iterable
# Error processing row 43: 'Movie' object is not iterable
# Error processing row 44: 'Movie' object is not iterable
# Error processing row 45: 'Movie' object is not iterable
# Error processing row 46: 'Movie' object is not iterable
# Error processing row 47: 'Movie' object is not iterable
# Error processing row 48: 'Movie' object is not iterable
# Error processing row 49: 'Movie' object is not iterable
# Error processing row 50: 'Movie' object is not iterable
# Error processing row 51: 'Movie' object is not iterable
# Error processing row 52: 'Movie' object is not iterable
# Error processing row 53: 'Movie' object is not iterable
# Error processing row 54: 'Movie' object is not iterable
# Error processing row 55: 'Movie' object is not iterable
# Error processing row 56: 'Movie' object is not iterable
# Error processing row 57: 'Movie' object is not iterable
# Error processing row 58: 'Movie' object is not iterable
# Error processing row 59: 'Movie' object is not iterable
# Error processing row 60: 'Movie' object is not iterable
# Error processing row 61: 'Movie' object is not iterable
# Error processing row 62: 'Movie' object is not iterable
# Error processing row 63: 'Movie' object is not iterable
# Error processing row 64: 'Movie' object is not iterable
# Error processing row 65: 'Movie' object is not iterable
# Error processing row 66: 'Movie' object is not iterable
# Error processing row 67: 'Movie' object is not iterable
# Error processing row 68: 'Movie' object is not iterable
# Error processing row 69: 'Movie' object is not iterable
# Error processing row 70: 'Movie' object is not iterable
# Error processing row 71: 'Movie' object is not iterable
# Error processing row 72: 'Movie' object is not iterable
# Error processing row 73: 'Movie' object is not iterable
# Error processing row 74: 'Movie' object is not iterable
# Error processing row 75: 'Movie' object is not iterable
# Error processing row 76: 'Movie' object is not iterable
# Error processing row 77: 'Movie' object is not iterable
# Error processing row 78: 'Movie' object is not iterable
# Error processing row 79: 'Movie' object is not iterable
# Error processing row 80: 'Movie' object is not iterable
# Error processing row 81: 'Movie' object is not iterable
# Error processing row 82: 'Movie' object is not iterable
# Error processing row 83: 'Movie' object is not iterable
# Error processing row 84: 'Movie' object is not iterable
# Error processing row 85: 'Movie' object is not iterable
# Error processing row 86: 'Movie' object is not iterable
# Error processing row 87: 'Movie' object is not iterable
# Error processing row 88: 'Movie' object is not iterable
# Error processing row 89: 'Movie' object is not iterable
# Error processing row 90: 'Movie' object is not iterable
# Error processing row 91: 'Movie' object is not iterable
# Error processing row 92: 'Movie' object is not iterable
# Error processing row 93: 'Movie' object is not iterable
# Error processing row 94: 'Movie' object is not iterable
# Error processing row 95: 'Movie' object is not iterable
# Error processing row 96: 'Movie' object is not iterable
# Error processing row 97: 'Movie' object is not iterable
# Error processing row 98: 'Movie' object is not iterable
# Error processing row 99: 'Movie' object is not iterable
# Error processing row 100: 'Movie' object is not iterable
# Error processing row 101: 'Movie' object is not iterable
# Error processing row 102: 'Movie' object is not iterable
# Error processing row 103: 'Movie' object is not iterable
# Error processing row 104: 'Movie' object is not iterable
# Error processing row 105: 'Movie' object is not iterable
# Error processing row 106: 'Movie' object is not iterable
# Error processing row 107: 'Movie' object is not iterable
# Error processing row 108: 'Movie' object is not iterable
# Error processing row 109: 'Movie' object is not iterable
# Error processing row 110: 'Movie' object is not iterable
# Error processing row 111: 'Movie' object is not iterable
# Error processing row 112: 'Movie' object is not iterable
# Error processing row 113: 'Movie' object is not iterable
# Error processing row 114: 'Movie' object is not iterable
# Error processing row 115: 'Movie' object is not iterable
# Error processing row 116: 'Movie' object is not iterable
# Error processing row 117: 'Movie' object is not iterable
# Error processing row 118: 'Movie' object is not iterable
# Error processing row 119: 'Movie' object is not iterable
# Error processing row 120: 'Movie' object is not iterable
# Error processing row 121: 'Movie' object is not iterable
# Error processing row 122: 'Movie' object is not iterable
# Error processing row 123: 'Movie' object is not iterable
# Error processing row 124: 'Movie' object is not iterable
# Error processing row 125: 'Movie' object is not iterable
# Error processing row 126: 'Movie' object is not iterable
# Error processing row 127: 'Movie' object is not iterable
# Error processing row 128: 'Movie' object is not iterable
# Error processing row 129: 'Movie' object is not iterable
# Error processing row 130: 'Movie' object is not iterable
# Error processing row 131: 'Movie' object is not iterable
# Error processing row 132: 'Movie' object is not iterable
# Error processing row 133: 'Movie' object is not iterable
# Error processing row 134: 'Movie' object is not iterable
# Error processing row 135: 'Movie' object is not iterable
# Error processing row 136: 'Movie' object is not iterable
# Error processing row 137: 'Movie' object is not iterable
# Error processing row 138: 'Movie' object is not iterable
# Error processing row 139: 'Movie' object is not iterable
# Error processing row 140: 'Movie' object is not iterable
# Error processing row 141: 'Movie' object is not iterable
# Error processing row 142: 'Movie' object is not iterable
# Error processing row 143: 'Movie' object is not iterable
# Error processing row 144: 'Movie' object is not iterable
# Error processing row 145: 'Movie' object is not iterable
# Error processing row 146: 'Movie' object is not iterable
# Error processing row 147: 'Movie' object is not iterable
# Error processing row 148: 'Movie' object is not iterable
# Error processing row 149: 'Movie' object is not iterable
# Error processing row 150: 'Movie' object is not iterable
# Error processing row 151: 'Movie' object is not iterable
# Error processing row 152: 'Movie' object is not iterable
# Error processing row 153: 'Movie' object is not iterable
# Error processing row 154: 'Movie' object is not iterable
# Error processing row 155: 'Movie' object is not iterable
# Error processing row 156: 'Movie' object is not iterable
# Error processing row 157: 'Movie' object is not iterable
# Error processing row 158: 'Movie' object is not iterable
# Error processing row 159: 'Movie' object is not iterable
# Error processing row 160: 'Movie' object is not iterable
# Error processing row 161: 'Movie' object is not iterable
# Error processing row 162: 'Movie' object is not iterable
# Error processing row 163: 'Movie' object is not iterable
# Error processing row 164: 'Movie' object is not iterable
# Error processing row 165: 'Movie' object is not iterable
# Error processing row 166: 'Movie' object is not iterable
# Error processing row 167: 'Movie' object is not iterable
# Error processing row 168: 'Movie' object is not iterable
# Error processing row 169: 'Movie' object is not iterable
# Error processing row 170: 'Movie' object is not iterable
# Error processing row 171: 'Movie' object is not iterable
# Error processing row 172: 'Movie' object is not iterable
# Error processing row 173: 'Movie' object is not iterable
# Error processing row 174: 'Movie' object is not iterable
# Error processing row 175: 'Movie' object is not iterable
# Error processing row 176: 'Movie' object is not iterable
# Error processing row 177: 'Movie' object is not iterable
# Error processing row 178: 'Movie' object is not iterable
# Error processing row 179: 'Movie' object is not iterable
# Error processing row 180: 'Movie' object is not iterable
# Error processing row 181: 'Movie' object is not iterable
# Error processing row 182: 'Movie' object is not iterable
# Error processing row 183: 'Movie' object is not iterable
# Error processing row 184: 'Movie' object is not iterable
# Error processing row 185: 'Movie' object is not iterable
# Error processing row 186: 'Movie' object is not iterable
# Error processing row 187: 'Movie' object is not iterable
# Error processing row 188: 'Movie' object is not iterable
# Error processing row 189: 'Movie' object is not iterable
# Error processing row 190: 'Movie' object is not iterable
# Error processing row 191: 'Movie' object is not iterable
# Error processing row 192: 'Movie' object is not iterable
# Error processing row 193: 'Movie' object is not iterable
# Error processing row 194: 'Movie' object is not iterable
# Error processing row 195: 'Movie' object is not iterable
# Error processing row 196: 'Movie' object is not iterable
# Error processing row 197: 'Movie' object is not iterable
# Error processing row 198: 'Movie' object is not iterable
# Error processing row 199: 'Movie' object is not iterable
# Error processing row 200: 'Movie' object is not iterable
# Error processing row 201: 'Movie' object is not iterable
# Error processing row 202: 'Movie' object is not iterable
# Error processing row 203: 'Movie' object is not iterable
# Error processing row 204: 'Movie' object is not iterable
# Error processing row 205: 'Movie' object is not iterable
# Error processing row 206: 'Movie' object is not iterable
# Error processing row 207: 'Movie' object is not iterable
# Error processing row 208: 'Movie' object is not iterable
# Error processing row 209: 'Movie' object is not iterable
# Error processing row 210: 'Movie' object is not iterable
# Error processing row 211: 'Movie' object is not iterable
# Error processing row 212: 'Movie' object is not iterable
# Error processing row 213: 'Movie' object is not iterable
# Error processing row 214: 'Movie' object is not iterable
# Error processing row 215: 'Movie' object is not iterable
# Error processing row 216: 'Movie' object is not iterable
# Error processing row 217: 'Movie' object is not iterable
# Error processing row 218: 'Movie' object is not iterable
# Error processing row 219: 'Movie' object is not iterable
# Error processing row 220: 'Movie' object is not iterable
# Error processing row 221: 'Movie' object is not iterable
# Error processing row 222: 'Movie' object is not iterable
# Error processing row 223: 'Movie' object is not iterable
# Error processing row 224: 'Movie' object is not iterable
# Error processing row 225: 'Movie' object is not iterable
# Error processing row 226: 'Movie' object is not iterable
# Error processing row 227: 'Movie' object is not iterable
# Error processing row 228: 'Movie' object is not iterable
# Error processing row 229: 'Movie' object is not iterable
# Error processing row 230: 'Movie' object is not iterable
# Error processing row 231: 'Movie' object is not iterable
# Error processing row 232: 'Movie' object is not iterable
# Error processing row 233: 'Movie' object is not iterable
# Error processing row 234: 'Movie' object is not iterable
# Error processing row 235: 'Movie' object is not iterable
# Error processing row 236: 'Movie' object is not iterable
# Error processing row 237: 'Movie' object is not iterable
# Error processing row 238: 'Movie' object is not iterable
# Error processing row 239: 'Movie' object is not iterable
# Error processing row 240: 'Movie' object is not iterable
# Error processing row 241: 'Movie' object is not iterable
# Error processing row 242: 'Movie' object is not iterable
# Error processing row 243: 'Movie' object is not iterable
# Error processing row 244: 'Movie' object is not iterable
# Error processing row 245: 'Movie' object is not iterable
# Error processing row 246: 'Movie' object is not iterable
# Error processing row 247: 'Movie' object is not iterable
# Error processing row 248: 'Movie' object is not iterable
# Error processing row 249: 'Movie' object is not iterable
# Error processing row 250: 'Movie' object is not iterable
# Error processing row 251: 'Movie' object is not iterable
# Error processing row 252: 'Movie' object is not iterable
# Error processing row 253: 'Movie' object is not iterable
# Error processing row 254: 'Movie' object is not iterable
# Error processing row 255: 'Movie' object is not iterable
# Error processing row 256: 'Movie' object is not iterable
# Error processing row 257: 'Movie' object is not iterable
# Error processing row 258: 'Movie' object is not iterable
# Error processing row 259: 'Movie' object is not iterable
# Error processing row 260: 'Movie' object is not iterable
# Error processing row 261: 'Movie' object is not iterable
# Error processing row 262: 'Movie' object is not iterable
# Error processing row 263: 'Movie' object is not iterable
# Error processing row 264: 'Movie' object is not iterable
# Error processing row 265: 'Movie' object is not iterable
# Error processing row 266: 'Movie' object is not iterable
# Error processing row 267: 'Movie' object is not iterable
# Error processing row 268: 'Movie' object is not iterable
# Error processing row 269: 'Movie' object is not iterable
# Error processing row 270: 'Movie' object is not iterable
# Error processing row 271: 'Movie' object is not iterable
# Error processing row 272: 'Movie' object is not iterable
# Error processing row 273: 'Movie' object is not iterable
# Error processing row 274: 'Movie' object is not iterable
# Error processing row 275: 'Movie' object is not iterable
# Error processing row 276: 'Movie' object is not iterable
# Error processing row 277: 'Movie' object is not iterable
# Error processing row 278: 'Movie' object is not iterable
# Error processing row 279: 'Movie' object is not iterable
# Error processing row 280: 'Movie' object is not iterable
# Error processing row 281: 'Movie' object is not iterable
# Error processing row 282: 'Movie' object is not iterable
# Error processing row 283: 'Movie' object is not iterable
# Error processing row 284: 'Movie' object is not iterable
# Error processing row 285: 'Movie' object is not iterable
# Error processing row 286: 'Movie' object is not iterable
# Error processing row 287: 'Movie' object is not iterable
# Error processing row 288: 'Movie' object is not iterable
# Error processing row 289: 'Movie' object is not iterable
# Error processing row 290: 'Movie' object is not iterable
# Error processing row 291: 'Movie' object is not iterable
# Error processing row 292: 'Movie' object is not iterable
# Error processing row 293: 'Movie' object is not iterable
# Error processing row 294: 'Movie' object is not iterable
# Error processing row 295: 'Movie' object is not iterable
# Error processing row 296: 'Movie' object is not iterable
# Error processing row 297: 'Movie' object is not iterable
# Error processing row 298: 'Movie' object is not iterable
# Error processing row 299: 'Movie' object is not iterable
# Error processing row 300: 'Movie' object is not iterable
# Error processing row 301: 'Movie' object is not iterable
# Error processing row 302: 'Movie' object is not iterable
# Error processing row 303: 'Movie' object is not iterable
# Error processing row 304: 'Movie' object is not iterable
# Error processing row 305: 'Movie' object is not iterable
# Error processing row 306: 'Movie' object is not iterable
# Error processing row 307: 'Movie' object is not iterable
# Error processing row 308: 'Movie' object is not iterable
# Error processing row 309: 'Movie' object is not iterable
# Error processing row 310: 'Movie' object is not iterable
# Error processing row 311: 'Movie' object is not iterable
# Error processing row 312: 'Movie' object is not iterable
# Error processing row 313: 'Movie' object is not iterable
# Error processing row 314: 'Movie' object is not iterable
# Error processing row 315: 'Movie' object is not iterable
# Error processing row 316: 'Movie' object is not iterable
# Error processing row 317: 'Movie' object is not iterable
# Error processing row 318: 'Movie' object is not iterable
# Error processing row 319: 'Movie' object is not iterable
# Error processing row 320: 'Movie' object is not iterable
# Error processing row 321: 'Movie' object is not iterable
# Error processing row 322: 'Movie' object is not iterable
# Error processing row 323: 'Movie' object is not iterable
# Error processing row 324: 'Movie' object is not iterable
# Error processing row 325: 'Movie' object is not iterable
# Error processing row 326: 'Movie' object is not iterable
# Error processing row 327: 'Movie' object is not iterable
# Error processing row 328: 'Movie' object is not iterable
# Error processing row 329: 'Movie' object is not iterable
# Error processing row 330: 'Movie' object is not iterable
# Error processing row 331: 'Movie' object is not iterable
# Error processing row 332: 'Movie' object is not iterable
# Error processing row 333: 'Movie' object is not iterable
# Error processing row 334: 'Movie' object is not iterable
# Error processing row 335: 'Movie' object is not iterable
# Error processing row 336: 'Movie' object is not iterable
# Error processing row 337: 'Movie' object is not iterable
# Error processing row 338: 'Movie' object is not iterable
# Error processing row 339: 'Movie' object is not iterable
# Error processing row 340: 'Movie' object is not iterable
# Error processing row 341: 'Movie' object is not iterable
# Error processing row 342: 'Movie' object is not iterable
# Error processing row 343: 'Movie' object is not iterable
# Error processing row 344: 'Movie' object is not iterable
# Error processing row 345: 'Movie' object is not iterable
# Error processing row 346: 'Movie' object is not iterable
# Error processing row 347: 'Movie' object is not iterable
# Error processing row 348: 'Movie' object is not iterable
# Error processing row 349: 'Movie' object is not iterable
# Error processing row 350: 'Movie' object is not iterable
# Error processing row 351: 'Movie' object is not iterable
# Error processing row 352: 'Movie' object is not iterable
# Error processing row 353: 'Movie' object is not iterable
# Error processing row 354: 'Movie' object is not iterable
# Error processing row 355: 'Movie' object is not iterable
# Error processing row 356: 'Movie' object is not iterable
# Error processing row 357: 'Movie' object is not iterable
# Error processing row 358: 'Movie' object is not iterable
# Error processing row 359: 'Movie' object is not iterable
# Error processing row 360: 'Movie' object is not iterable
# Error processing row 361: 'Movie' object is not iterable
# Error processing row 362: 'Movie' object is not iterable
# Error processing row 363: 'Movie' object is not iterable
# Error processing row 364: 'Movie' object is not iterable
# Error processing row 365: 'Movie' object is not iterable
# Error processing row 366: 'Movie' object is not iterable
# Error processing row 367: 'Movie' object is not iterable
# Error processing row 368: 'Movie' object is not iterable
# Error processing row 369: 'Movie' object is not iterable
# Error processing row 370: 'Movie' object is not iterable
# Error processing row 371: 'Movie' object is not iterable
# Error processing row 372: 'Movie' object is not iterable
# Error processing row 373: 'Movie' object is not iterable
# Error processing row 374: 'Movie' object is not iterable
# Error processing row 375: 'Movie' object is not iterable
# Error processing row 376: 'Movie' object is not iterable
# Error processing row 377: 'Movie' object is not iterable
# Error processing row 378: 'Movie' object is not iterable
# Error processing row 379: 'Movie' object is not iterable
# Error processing row 380: 'Movie' object is not iterable
# Error processing row 381: 'Movie' object is not iterable
# Error processing row 382: 'Movie' object is not iterable
# Error processing row 383: 'Movie' object is not iterable
# Error processing row 384: 'Movie' object is not iterable
# Error processing row 385: 'Movie' object is not iterable
# Error processing row 386: 'Movie' object is not iterable
# Error processing row 387: 'Movie' object is not iterable
# Error processing row 388: 'Movie' object is not iterable
# Error processing row 389: 'Movie' object is not iterable
# Error processing row 390: 'Movie' object is not iterable
# Error processing row 391: 'Movie' object is not iterable
# Error processing row 392: 'Movie' object is not iterable
# Error processing row 393: 'Movie' object is not iterable
# Error processing row 394: 'Movie' object is not iterable
# Error processing row 395: 'Movie' object is not iterable
# Error processing row 396: 'Movie' object is not iterable
# Error processing row 397: 'Movie' object is not iterable
# Error processing row 398: 'Movie' object is not iterable
# Error processing row 399: 'Movie' object is not iterable
# Error processing row 400: 'Movie' object is not iterable
# Error processing row 401: 'Movie' object is not iterable
# Error processing row 402: 'Movie' object is not iterable
# Error processing row 403: 'Movie' object is not iterable
# Error processing row 404: 'Movie' object is not iterable
# Error processing row 405: 'Movie' object is not iterable
# Error processing row 406: 'Movie' object is not iterable
# Error processing row 407: 'Movie' object is not iterable
# Error processing row 408: 'Movie' object is not iterable
# Error processing row 409: 'Movie' object is not iterable
# Error processing row 410: 'Movie' object is not iterable
# Error processing row 411: 'Movie' object is not iterable
# Error processing row 412: 'Movie' object is not iterable
# Error processing row 413: 'Movie' object is not iterable
# Error processing row 414: 'Movie' object is not iterable
# Error processing row 415: 'Movie' object is not iterable
# Error processing row 416: 'Movie' object is not iterable
# Error processing row 417: 'Movie' object is not iterable
# Error processing row 418: 'Movie' object is not iterable
# Error processing row 419: 'Movie' object is not iterable
# Error processing row 420: 'Movie' object is not iterable
# Error processing row 421: 'Movie' object is not iterable
# Error processing row 422: 'Movie' object is not iterable
# Error processing row 423: 'Movie' object is not iterable
# Error processing row 424: 'Movie' object is not iterable
# Error processing row 425: 'Movie' object is not iterable
# Error processing row 426: 'Movie' object is not iterable
# Error processing row 427: 'Movie' object is not iterable
# Error processing row 428: 'Movie' object is not iterable
# Error processing row 429: 'Movie' object is not iterable
# Error processing row 430: 'Movie' object is not iterable
# Error processing row 431: 'Movie' object is not iterable
# Error processing row 432: 'Movie' object is not iterable
# Error processing row 433: 'Movie' object is not iterable
# Error processing row 434: 'Movie' object is not iterable
# Error processing row 435: 'Movie' object is not iterable
# Error processing row 436: 'Movie' object is not iterable
# Error processing row 437: 'Movie' object is not iterable
# Error processing row 438: 'Movie' object is not iterable
# Error processing row 439: 'Movie' object is not iterable
# Error processing row 440: 'Movie' object is not iterable
# Error processing row 441: 'Movie' object is not iterable
# Error processing row 442: 'Movie' object is not iterable
# Error processing row 443: 'Movie' object is not iterable
# Error processing row 444: 'Movie' object is not iterable
# Error processing row 445: 'Movie' object is not iterable
# Error processing row 446: 'Movie' object is not iterable
# Error processing row 447: 'Movie' object is not iterable
# Error processing row 448: 'Movie' object is not iterable
# Error processing row 449: 'Movie' object is not iterable
# Error processing row 450: 'Movie' object is not iterable
# Error processing row 451: 'Movie' object is not iterable
# Error processing row 452: 'Movie' object is not iterable
# Error processing row 453: 'Movie' object is not iterable
# Error processing row 454: 'Movie' object is not iterable
# Error processing row 455: 'Movie' object is not iterable
# Error processing row 456: 'Movie' object is not iterable
# Error processing row 457: 'Movie' object is not iterable
# Error processing row 458: 'Movie' object is not iterable
# Error processing row 459: 'Movie' object is not iterable
# Error processing row 460: 'Movie' object is not iterable
# Error processing row 461: 'Movie' object is not iterable
# Error processing row 462: 'Movie' object is not iterable
# Error processing row 463: 'Movie' object is not iterable
# Error processing row 464: 'Movie' object is not iterable
# Error processing row 465: 'Movie' object is not iterable
# Error processing row 466: 'Movie' object is not iterable
# Error processing row 467: 'Movie' object is not iterable
# Error processing row 468: 'Movie' object is not iterable
# Error processing row 469: 'Movie' object is not iterable
# Error processing row 470: 'Movie' object is not iterable
# Error processing row 471: 'Movie' object is not iterable
# Error processing row 472: 'Movie' object is not iterable
# Error processing row 473: 'Movie' object is not iterable
# Error processing row 474: 'Movie' object is not iterable
# Error processing row 475: 'Movie' object is not iterable
# Error processing row 476: 'Movie' object is not iterable
# Error processing row 477: 'Movie' object is not iterable
# Error processing row 478: 'Movie' object is not iterable
# Error processing row 479: 'Movie' object is not iterable
# Error processing row 480: 'Movie' object is not iterable
# Error processing row 481: 'Movie' object is not iterable
# Error processing row 482: 'Movie' object is not iterable
# Error processing row 483: 'Movie' object is not iterable
# Error processing row 484: 'Movie' object is not iterable
# Error processing row 485: 'Movie' object is not iterable
# Error processing row 486: 'Movie' object is not iterable
# Error processing row 487: 'Movie' object is not iterable
# Error processing row 488: 'Movie' object is not iterable
# Error processing row 489: 'Movie' object is not iterable
# Error processing row 490: 'Movie' object is not iterable
# Error processing row 491: 'Movie' object is not iterable
# Error processing row 492: 'Movie' object is not iterable
# Error processing row 493: 'Movie' object is not iterable
# Error processing row 494: 'Movie' object is not iterable
# Error processing row 495: 'Movie' object is not iterable
# Error processing row 496: 'Movie' object is not iterable
# Error processing row 497: 'Movie' object is not iterable
# Error processing row 498: 'Movie' object is not iterable
# Error processing row 499: 'Movie' object is not iterable
# Error processing row 500: 'Movie' object is not iterable
# Error processing row 501: 'Movie' object is not iterable
# Error processing row 502: 'Movie' object is not iterable
# Error processing row 503: 'Movie' object is not iterable
# Error processing row 504: 'Movie' object is not iterable
# Error processing row 505: 'Movie' object is not iterable
# Error processing row 506: 'Movie' object is not iterable
# Error processing row 507: 'Movie' object is not iterable
# Error processing row 508: 'Movie' object is not iterable
# Error processing row 509: 'Movie' object is not iterable
# Error processing row 510: 'Movie' object is not iterable
# Error processing row 511: 'Movie' object is not iterable
# Error processing row 512: 'Movie' object is not iterable
# Error processing row 513: 'Movie' object is not iterable
# Error processing row 514: 'Movie' object is not iterable
# Error processing row 515: 'Movie' object is not iterable
# Error processing row 516: 'Movie' object is not iterable
# Error processing row 517: 'Movie' object is not iterable
# Error processing row 518: 'Movie' object is not iterable
# Error processing row 519: 'Movie' object is not iterable
# Error processing row 520: 'Movie' object is not iterable
# Error processing row 521: 'Movie' object is not iterable
# Error processing row 522: 'Movie' object is not iterable
# Error processing row 523: 'Movie' object is not iterable
# Error processing row 524: 'Movie' object is not iterable
# Error processing row 525: 'Movie' object is not iterable
# Error processing row 526: 'Movie' object is not iterable
# Error processing row 527: 'Movie' object is not iterable
# Error processing row 528: 'Movie' object is not iterable
# Error processing row 529: 'Movie' object is not iterable
# Error processing row 530: 'Movie' object is not iterable
# Error processing row 531: 'Movie' object is not iterable
# Error processing row 532: 'Movie' object is not iterable
# Error processing row 533: 'Movie' object is not iterable
# Error processing row 534: 'Movie' object is not iterable
# Error processing row 535: 'Movie' object is not iterable
# Error processing row 536: 'Movie' object is not iterable
# Error processing row 537: 'Movie' object is not iterable
# Error processing row 538: 'Movie' object is not iterable
# Error processing row 539: 'Movie' object is not iterable
# Error processing row 540: 'Movie' object is not iterable
# Error processing row 541: 'Movie' object is not iterable
# Error processing row 542: 'Movie' object is not iterable
# Error processing row 543: 'Movie' object is not iterable
# Error processing row 544: 'Movie' object is not iterable
# Error processing row 545: 'Movie' object is not iterable
# Error processing row 546: 'Movie' object is not iterable
# Error processing row 547: 'Movie' object is not iterable
# Error processing row 548: 'Movie' object is not iterable
# Error processing row 549: 'Movie' object is not iterable
# Error processing row 550: 'Movie' object is not iterable
# Error processing row 551: 'Movie' object is not iterable
# Error processing row 552: 'Movie' object is not iterable
# Error processing row 553: 'Movie' object is not iterable
# Error processing row 554: 'Movie' object is not iterable
# Error processing row 555: 'Movie' object is not iterable
# Error processing row 556: 'Movie' object is not iterable
# Error processing row 557: 'Movie' object is not iterable
# Error processing row 558: 'Movie' object is not iterable
# Error processing row 559: 'Movie' object is not iterable
# Error processing row 560: 'Movie' object is not iterable
# Error processing row 561: 'Movie' object is not iterable
# Error processing row 562: 'Movie' object is not iterable
# Error processing row 563: 'Movie' object is not iterable
# Error processing row 564: 'Movie' object is not iterable
# Error processing row 565: 'Movie' object is not iterable
# Error processing row 566: 'Movie' object is not iterable
# Error processing row 567: 'Movie' object is not iterable
# Error processing row 568: 'Movie' object is not iterable
# Error processing row 569: 'Movie' object is not iterable
# Error processing row 570: 'Movie' object is not iterable
# Error processing row 571: 'Movie' object is not iterable
# Error processing row 572: 'Movie' object is not iterable
# Error processing row 573: 'Movie' object is not iterable
# Error processing row 574: 'Movie' object is not iterable
# Error processing row 575: 'Movie' object is not iterable
# Error processing row 576: 'Movie' object is not iterable
# Error processing row 577: 'Movie' object is not iterable
# Error processing row 578: 'Movie' object is not iterable
# Error processing row 579: 'Movie' object is not iterable
# Error processing row 580: 'Movie' object is not iterable
# Error processing row 581: 'Movie' object is not iterable
# Error processing row 582: 'Movie' object is not iterable
# Error processing row 583: 'Movie' object is not iterable
# Error processing row 584: 'Movie' object is not iterable
# Error processing row 585: 'Movie' object is not iterable
# Error processing row 586: 'Movie' object is not iterable
# Error processing row 587: 'Movie' object is not iterable
# Error processing row 588: 'Movie' object is not iterable
# Error processing row 589: 'Movie' object is not iterable
# Error processing row 590: 'Movie' object is not iterable
# Error processing row 591: 'Movie' object is not iterable
# Error processing row 592: 'Movie' object is not iterable
# Error processing row 593: 'Movie' object is not iterable
# Error processing row 594: 'Movie' object is not iterable
# Error processing row 595: 'Movie' object is not iterable
# Error processing row 596: 'Movie' object is not iterable
# Error processing row 597: 'Movie' object is not iterable
# Error processing row 598: 'Movie' object is not iterable
# Error processing row 599: 'Movie' object is not iterable
# Error processing row 600: 'Movie' object is not iterable
# Error processing row 601: 'Movie' object is not iterable
# Error processing row 602: 'Movie' object is not iterable
# Error processing row 603: 'Movie' object is not iterable
# Error processing row 604: 'Movie' object is not iterable
# Error processing row 605: 'Movie' object is not iterable
# Error processing row 606: 'Movie' object is not iterable
# Error processing row 607: 'Movie' object is not iterable
# Error processing row 608: 'Movie' object is not iterable
# Error processing row 609: 'Movie' object is not iterable
# Error processing row 610: 'Movie' object is not iterable
# Error processing row 611: 'Movie' object is not iterable
# Error processing row 612: 'Movie' object is not iterable
# Error processing row 613: 'Movie' object is not iterable
# Error processing row 614: 'Movie' object is not iterable
# Error processing row 615: 'Movie' object is not iterable
# Error processing row 616: 'Movie' object is not iterable
# Error processing row 617: 'Movie' object is not iterable
# Error processing row 618: 'Movie' object is not iterable
# Error processing row 619: 'Movie' object is not iterable
# Error processing row 620: 'Movie' object is not iterable
# Error processing row 621: 'Movie' object is not iterable
# Error processing row 622: 'Movie' object is not iterable
# Error processing row 623: 'Movie' object is not iterable
# Error processing row 624: 'Movie' object is not iterable
# Error processing row 625: 'Movie' object is not iterable
# Error processing row 626: 'Movie' object is not iterable
# Error processing row 627: 'Movie' object is not iterable
# Error processing row 628: 'Movie' object is not iterable
# Error processing row 629: 'Movie' object is not iterable
# Error processing row 630: 'Movie' object is not iterable
# Error processing row 631: 'Movie' object is not iterable
# Error processing row 632: 'Movie' object is not iterable
# Error processing row 633: 'Movie' object is not iterable
# Error processing row 634: 'Movie' object is not iterable
# Error processing row 635: 'Movie' object is not iterable
# Error processing row 636: 'Movie' object is not iterable
# Error processing row 637: 'Movie' object is not iterable
# Error processing row 638: 'Movie' object is not iterable
# Error processing row 639: 'Movie' object is not iterable
# Error processing row 640: 'Movie' object is not iterable
# Error processing row 641: 'Movie' object is not iterable
# Error processing row 642: 'Movie' object is not iterable
# Error processing row 643: 'Movie' object is not iterable
# Error processing row 644: 'Movie' object is not iterable
# Error processing row 645: 'Movie' object is not iterable
# Error processing row 646: 'Movie' object is not iterable
# Error processing row 647: 'Movie' object is not iterable
# Error processing row 648: 'Movie' object is not iterable
# Error processing row 649: 'Movie' object is not iterable
# Error processing row 650: 'Movie' object is not iterable
# Error processing row 651: 'Movie' object is not iterable
# Error processing row 652: 'Movie' object is not iterable
# Error processing row 653: 'Movie' object is not iterable
# Error processing row 654: 'Movie' object is not iterable
# Error processing row 655: 'Movie' object is not iterable
# Error processing row 656: 'Movie' object is not iterable
# Error processing row 657: 'Movie' object is not iterable
# Error processing row 658: 'Movie' object is not iterable
# Error processing row 659: 'Movie' object is not iterable
# Error processing row 660: 'Movie' object is not iterable
# Error processing row 661: 'Movie' object is not iterable
# Error processing row 662: 'Movie' object is not iterable
# Error processing row 663: 'Movie' object is not iterable
# Error processing row 664: 'Movie' object is not iterable
# Error processing row 665: 'Movie' object is not iterable
# Error processing row 666: 'Movie' object is not iterable
# Error processing row 667: 'Movie' object is not iterable
# Error processing row 668: 'Movie' object is not iterable
# Error processing row 669: 'Movie' object is not iterable
# Error processing row 670: 'Movie' object is not iterable
# Error processing row 671: 'Movie' object is not iterable
# Error processing row 672: 'Movie' object is not iterable
# Error processing row 673: 'Movie' object is not iterable
# Error processing row 674: 'Movie' object is not iterable
# Error processing row 675: 'Movie' object is not iterable
# Error processing row 676: 'Movie' object is not iterable
# Error processing row 677: 'Movie' object is not iterable
# Error processing row 678: 'Movie' object is not iterable
# Error processing row 679: 'Movie' object is not iterable
# Error processing row 680: 'Movie' object is not iterable
# Error processing row 681: 'Movie' object is not iterable
# Error processing row 682: 'Movie' object is not iterable
# Error processing row 683: 'Movie' object is not iterable
# Error processing row 684: 'Movie' object is not iterable
# Error processing row 685: 'Movie' object is not iterable
# Error processing row 686: 'Movie' object is not iterable
# Error processing row 687: 'Movie' object is not iterable
# Error processing row 688: 'Movie' object is not iterable
# Error processing row 689: 'Movie' object is not iterable
# Error processing row 690: 'Movie' object is not iterable
# Error processing row 691: 'Movie' object is not iterable
# Error processing row 692: 'Movie' object is not iterable
# Error processing row 693: 'Movie' object is not iterable
# Error processing row 694: 'Movie' object is not iterable
# Error processing row 695: 'Movie' object is not iterable
# Error processing row 696: 'Movie' object is not iterable
# Error processing row 697: 'Movie' object is not iterable
# Error processing row 698: 'Movie' object is not iterable
# Error processing row 699: 'Movie' object is not iterable
# Error processing row 700: 'Movie' object is not iterable
# Error processing row 701: 'Movie' object is not iterable
# Error processing row 702: 'Movie' object is not iterable
# Error processing row 703: 'Movie' object is not iterable
# Error processing row 704: 'Movie' object is not iterable
# Error processing row 705: 'Movie' object is not iterable
# Error processing row 706: 'Movie' object is not iterable
# Error processing row 707: 'Movie' object is not iterable
# Error processing row 708: 'Movie' object is not iterable
# Error processing row 709: 'Movie' object is not iterable
# Error processing row 710: 'Movie' object is not iterable
# Error processing row 711: 'Movie' object is not iterable
# Error processing row 712: 'Movie' object is not iterable
# Error processing row 713: 'Movie' object is not iterable
# Error processing row 714: 'Movie' object is not iterable
# Error processing row 715: 'Movie' object is not iterable
# Error processing row 716: 'Movie' object is not iterable
# Error processing row 717: 'Movie' object is not iterable
# Error processing row 718: 'Movie' object is not iterable
# Error processing row 719: 'Movie' object is not iterable
# Error processing row 720: 'Movie' object is not iterable
# Error processing row 721: 'Movie' object is not iterable
# Error processing row 722: 'Movie' object is not iterable
# Error processing row 723: 'Movie' object is not iterable
# Error processing row 724: 'Movie' object is not iterable
# Error processing row 725: 'Movie' object is not iterable
# Error processing row 726: 'Movie' object is not iterable
# Error processing row 727: 'Movie' object is not iterable
# Error processing row 728: 'Movie' object is not iterable
# Error processing row 729: 'Movie' object is not iterable
# Error processing row 730: 'Movie' object is not iterable
# Error processing row 731: 'Movie' object is not iterable
# Error processing row 732: 'Movie' object is not iterable
# Error processing row 733: 'Movie' object is not iterable
# Error processing row 734: 'Movie' object is not iterable
# Error processing row 735: 'Movie' object is not iterable
# Error processing row 736: 'Movie' object is not iterable
# Error processing row 737: 'Movie' object is not iterable
# Error processing row 738: 'Movie' object is not iterable
# Error processing row 739: 'Movie' object is not iterable
# Error processing row 740: 'Movie' object is not iterable
# Error processing row 741: 'Movie' object is not iterable
# Error processing row 742: 'Movie' object is not iterable
# Error processing row 743: 'Movie' object is not iterable
# Error processing row 744: 'Movie' object is not iterable
# Error processing row 745: 'Movie' object is not iterable
# Error processing row 746: 'Movie' object is not iterable
# Error processing row 747: 'Movie' object is not iterable
# Error processing row 748: 'Movie' object is not iterable
# Error processing row 749: 'Movie' object is not iterable
# Error processing row 750: 'Movie' object is not iterable
# Error processing row 751: 'Movie' object is not iterable
# Error processing row 752: 'Movie' object is not iterable
# Error processing row 753: 'Movie' object is not iterable
# Error processing row 754: 'Movie' object is not iterable
# Error processing row 755: 'Movie' object is not iterable
# Error processing row 756: 'Movie' object is not iterable
# Error processing row 757: 'Movie' object is not iterable
# Error processing row 758: 'Movie' object is not iterable
# Error processing row 759: 'Movie' object is not iterable
# Error processing row 760: 'Movie' object is not iterable
# Error processing row 761: 'Movie' object is not iterable
# Error processing row 762: 'Movie' object is not iterable
# Error processing row 763: 'Movie' object is not iterable
# Error processing row 764: 'Movie' object is not iterable
# Error processing row 765: 'Movie' object is not iterable
# Error processing row 766: 'Movie' object is not iterable
# Error processing row 767: 'Movie' object is not iterable
# Error processing row 768: 'Movie' object is not iterable
# Error processing row 769: 'Movie' object is not iterable
# Error processing row 770: 'Movie' object is not iterable
# Error processing row 771: 'Movie' object is not iterable
# Error processing row 772: 'Movie' object is not iterable
# Error processing row 773: 'Movie' object is not iterable
# Error processing row 774: 'Movie' object is not iterable
# Error processing row 775: 'Movie' object is not iterable
# Error processing row 776: 'Movie' object is not iterable
# Error processing row 777: 'Movie' object is not iterable
# Error processing row 778: 'Movie' object is not iterable
# Error processing row 779: 'Movie' object is not iterable
# Error processing row 780: 'Movie' object is not iterable
# Error processing row 781: 'Movie' object is not iterable
# Error processing row 782: 'Movie' object is not iterable
# Error processing row 783: 'Movie' object is not iterable
# Error processing row 784: 'Movie' object is not iterable
# Error processing row 785: 'Movie' object is not iterable
# Error processing row 786: 'Movie' object is not iterable
# Error processing row 787: 'Movie' object is not iterable
# Error processing row 788: 'Movie' object is not iterable
# Error processing row 789: 'Movie' object is not iterable
# Error processing row 790: 'Movie' object is not iterable
# Error processing row 791: 'Movie' object is not iterable
# Error processing row 792: 'Movie' object is not iterable
# Error processing row 793: 'Movie' object is not iterable
# Error processing row 794: 'Movie' object is not iterable
# Error processing row 795: 'Movie' object is not iterable
# Error processing row 796: 'Movie' object is not iterable
# Error processing row 797: 'Movie' object is not iterable
# Error processing row 798: 'Movie' object is not iterable
# Error processing row 799: 'Movie' object is not iterable
# Error processing row 800: 'Movie' object is not iterable
# Error processing row 801: 'Movie' object is not iterable
# Error processing row 802: 'Movie' object is not iterable
# Error processing row 803: 'Movie' object is not iterable
# Error processing row 804: 'Movie' object is not iterable
# Error processing row 805: 'Movie' object is not iterable
# Error processing row 806: 'Movie' object is not iterable
# Error processing row 807: 'Movie' object is not iterable
# Error processing row 808: 'Movie' object is not iterable
# Error processing row 809: 'Movie' object is not iterable
# Error processing row 810: 'Movie' object is not iterable
# Error processing row 811: 'Movie' object is not iterable
# Error processing row 812: 'Movie' object is not iterable
# Error processing row 813: 'Movie' object is not iterable
# Error processing row 814: 'Movie' object is not iterable
# Error processing row 815: 'Movie' object is not iterable
# Error processing row 816: 'Movie' object is not iterable
# Error processing row 817: 'Movie' object is not iterable
# Error processing row 818: 'Movie' object is not iterable
# Error processing row 819: 'Movie' object is not iterable
# Error processing row 820: 'Movie' object is not iterable
# Error processing row 821: 'Movie' object is not iterable
# Error processing row 822: 'Movie' object is not iterable
# Error processing row 823: 'Movie' object is not iterable
# Error processing row 824: 'Movie' object is not iterable
# Error processing row 825: 'Movie' object is not iterable
# Error processing row 826: 'Movie' object is not iterable
# Error processing row 827: 'Movie' object is not iterable
# Error processing row 828: 'Movie' object is not iterable
# Error processing row 829: 'Movie' object is not iterable
# Error processing row 830: 'Movie' object is not iterable
# Error processing row 831: 'Movie' object is not iterable
# Error processing row 832: 'Movie' object is not iterable
# Error processing row 833: 'Movie' object is not iterable
# Error processing row 834: 'Movie' object is not iterable
# Error processing row 835: 'Movie' object is not iterable
# Error processing row 836: 'Movie' object is not iterable
# Error processing row 837: 'Movie' object is not iterable
# Error processing row 838: 'Movie' object is not iterable
# Error processing row 839: 'Movie' object is not iterable
# Error processing row 840: 'Movie' object is not iterable
# Error processing row 841: 'Movie' object is not iterable
# Error processing row 842: 'Movie' object is not iterable
# Error processing row 843: 'Movie' object is not iterable
# ...
# Error processing row 1022: 'Movie' object is not iterable
# Error processing row 1023: 'Movie' object is not iterable
# Error processing row 1024: 'Movie' object is not iterable
# Error processing row 1025: 'Movie' object is not iterable
# Error processing row 1026: 'Movie' object is not iterable
# Error processing row 1027: 'Movie' object is not iterable
# Error processing row 1028: 'Movie' object is not iterable
# Error processing row 1029: 'Movie' object is not iterable
# Error processing row 1030: 'Movie' object is not iterable
# Error processing row 1031: 'Movie' object is not iterable
# Error processing row 1032: 'Movie' object is not iterable
# Error processing row 1033: 'Movie' object is not iterable
# Error processing row 1034: 'Movie' object is not iterable
# Error processing row 1035: 'Movie' object is not iterable
# Error processing row 1036: 'Movie' object is not iterable
# Error processing row 1037: 'Movie' object is not iterable
# Error processing row 1038: 'Movie' object is not iterable
# Error processing row 1039: 'Movie' object is not iterable
# Error processing row 1040: 'Movie' object is not iterable
# Error processing row 1041: 'Movie' object is not iterable
# Error processing row 1042: 'Movie' object is not iterable
# Error processing row 1043: 'Movie' object is not iterable
# Error processing row 1044: 'Movie' object is not iterable
# Error processing row 1045: 'Movie' object is not iterable
# Error processing row 1046: 'Movie' object is not iterable
# Error processing row 1047: 'Movie' object is not iterable
# Error processing row 1048: 'Movie' object is not iterable
# Error processing row 1049: 'Movie' object is not iterable
# Error processing row 1050: 'Movie' object is not iterable
# Error processing row 1051: 'Movie' object is not iterable
# Error processing row 1052: 'Movie' object is not iterable
# Error processing row 1053: 'Movie' object is not iterable
# Error processing row 1054: 'Movie' object is not iterable
# Error processing row 1055: 'Movie' object is not iterable
# Error processing row 1056: 'Movie' object is not iterable
# Error processing row 1057: 'Movie' object is not iterable
# Error processing row 1058: 'Movie' object is not iterable
# Error processing row 1059: 'Movie' object is not iterable
# Error processing row 1060: 'Movie' object is not iterable
# Error processing row 1061: 'Movie' object is not iterable
# Error processing row 1062: 'Movie' object is not iterable
# Error processing row 1063: 'Movie' object is not iterable
# Error processing row 1064: 'Movie' object is not iterable
# Error processing row 1065: 'Movie' object is not iterable
# Error processing row 1066: 'Movie' object is not iterable
# Error processing row 1067: 'Movie' object is not iterable
# Error processing row 1068: 'Movie' object is not iterable
# Error processing row 1069: 'Movie' object is not iterable
# Error processing row 1070: 'Movie' object is not iterable
# Error processing row 1071: 'Movie' object is not iterable
# Error processing row 1072: 'Movie' object is not iterable
# Error processing row 1073: 'Movie' object is not iterable
# Error processing row 1074: 'Movie' object is not iterable
# Error processing row 1075: 'Movie' object is not iterable
# Error processing row 1076: 'Movie' object is not iterable
# Error processing row 1077: 'Movie' object is not iterable
# Error processing row 1078: 'Movie' object is not iterable
# Error processing row 1079: 'Movie' object is not iterable
# Error processing row 1080: 'Movie' object is not iterable
# Error processing row 1081: 'Movie' object is not iterable
# Error processing row 1082: 'Movie' object is not iterable
# Error processing row 1083: 'Movie' object is not iterable
# Error processing row 1084: 'Movie' object is not iterable
# Error processing row 1085: 'Movie' object is not iterable
# Error processing row 1086: 'Movie' object is not iterable
# Error processing row 1087: 'Movie' object is not iterable
# Error processing row 1088: 'Movie' object is not iterable
# Error processing row 1089: 'Movie' object is not iterable
# Error processing row 1090: 'Movie' object is not iterable
# Error processing row 1091: 'Movie' object is not iterable
# Error processing row 1092: 'Movie' object is not iterable
# Error processing row 1093: 'Movie' object is not iterable
# Error processing row 1094: 'Movie' object is not iterable
# Error processing row 1095: 'Movie' object is not iterable
# Error processing row 1096: 'Movie' object is not iterable
# Error processing row 1097: 'Movie' object is not iterable
# Error processing row 1098: 'Movie' object is not iterable
# Error processing row 1099: 'Movie' object is not iterable
# Error processing row 1100: 'Movie' object is not iterable
# Error processing row 1101: 'Movie' object is not iterable
# Error processing row 1102: 'Movie' object is not iterable
# Error processing row 1103: 'Movie' object is not iterable
# Error processing row 1104: 'Movie' object is not iterable
# Error processing row 1105: 'Movie' object is not iterable
# Error processing row 1106: 'Movie' object is not iterable
# Error processing row 1107: 'Movie' object is not iterable
# Error processing row 1108: 'Movie' object is not iterable
# Error processing row 1109: 'Movie' object is not iterable
# Error processing row 1110: 'Movie' object is not iterable
# Error processing row 1111: 'Movie' object is not iterable
# Error processing row 1112: 'Movie' object is not iterable
# Error processing row 1113: 'Movie' object is not iterable
# Error processing row 1114: 'Movie' object is not iterable
# Error processing row 1115: 'Movie' object is not iterable
# Error processing row 1116: 'Movie' object is not iterable
# Error processing row 1117: 'Movie' object is not iterable
# Error processing row 1118: 'Movie' object is not iterable
# Error processing row 1119: 'Movie' object is not iterable
# Error processing row 1120: 'Movie' object is not iterable
# Error processing row 1121: 'Movie' object is not iterable
# Error processing row 1122: 'Movie' object is not iterable
# Error processing row 1123: 'Movie' object is not iterable
# Error processing row 1124: 'Movie' object is not iterable
# Error processing row 1125: 'Movie' object is not iterable
# Error processing row 1126: 'Movie' object is not iterable
# Error processing row 1127: 'Movie' object is not iterable
# Error processing row 1128: 'Movie' object is not iterable
# Error processing row 1129: 'Movie' object is not iterable
# Error processing row 1130: 'Movie' object is not iterable
# Error processing row 1131: 'Movie' object is not iterable
# Error processing row 1132: 'Movie' object is not iterable
# Error processing row 1133: 'Movie' object is not iterable
# Error processing row 1134: 'Movie' object is not iterable
# Error processing row 1135: 'Movie' object is not iterable
# Error processing row 1136: 'Movie' object is not iterable
# Error processing row 1137: 'Movie' object is not iterable
# Error processing row 1138: 'Movie' object is not iterable
# Error processing row 1139: 'Movie' object is not iterable
# Error processing row 1140: 'Movie' object is not iterable
# Error processing row 1141: 'Movie' object is not iterable
# Error processing row 1142: 'Movie' object is not iterable
# Error processing row 1143: 'Movie' object is not iterable
# Error processing row 1144: 'Movie' object is not iterable
# Error processing row 1145: 'Movie' object is not iterable
# Error processing row 1146: 'Movie' object is not iterable
# Error processing row 1147: 'Movie' object is not iterable
# Error processing row 1148: 'Movie' object is not iterable
# Error processing row 1149: 'Movie' object is not iterable
# Error processing row 1150: 'Movie' object is not iterable
# Error processing row 1151: 'Movie' object is not iterable
# Error processing row 1152: 'Movie' object is not iterable
# Error processing row 1153: 'Movie' object is not iterable
# Error processing row 1154: 'Movie' object is not iterable
# Error processing row 1155: 'Movie' object is not iterable
# Error processing row 1156: 'Movie' object is not iterable
# Error processing row 1157: 'Movie' object is not iterable
# Error processing row 1158: 'Movie' object is not iterable
# Error processing row 1159: 'Movie' object is not iterable
# Error processing row 1160: 'Movie' object is not iterable
# Error processing row 1161: 'Movie' object is not iterable
# Error processing row 1162: 'Movie' object is not iterable
# Error processing row 1163: 'Movie' object is not iterable
# Error processing row 1164: 'Movie' object is not iterable
# Error processing row 1165: 'Movie' object is not iterable
# Error processing row 1166: 'Movie' object is not iterable
# Error processing row 1167: 'Movie' object is not iterable
# Error processing row 1168: 'Movie' object is not iterable
# Error processing row 1169: 'Movie' object is not iterable
# Error processing row 1170: 'Movie' object is not iterable
# Error processing row 1171: 'Movie' object is not iterable
# Error processing row 1172: 'Movie' object is not iterable
# Error processing row 1173: 'Movie' object is not iterable
# Error processing row 1174: 'Movie' object is not iterable
# Error processing row 1175: 'Movie' object is not iterable
# Error processing row 1176: 'Movie' object is not iterable
# Error processing row 1177: 'Movie' object is not iterable
# Error processing row 1178: 'Movie' object is not iterable
# Error processing row 1179: 'Movie' object is not iterable
# Error processing row 1180: 'Movie' object is not iterable
# Error processing row 1181: 'Movie' object is not iterable
# Error processing row 1182: 'Movie' object is not iterable
# Error processing row 1183: 'Movie' object is not iterable
# Error processing row 1184: 'Movie' object is not iterable
# Error processing row 1185: 'Movie' object is not iterable
# Error processing row 1186: 'Movie' object is not iterable
# Error processing row 1187: 'Movie' object is not iterable
# Error processing row 1188: 'Movie' object is not iterable
# Error processing row 1189: 'Movie' object is not iterable
# Error processing row 1190: 'Movie' object is not iterable
# Error processing row 1191: 'Movie' object is not iterable
# Error processing row 1192: 'Movie' object is not iterable
# Error processing row 1193: 'Movie' object is not iterable
# Error processing row 1194: 'Movie' object is not iterable
# Error processing row 1195: 'Movie' object is not iterable
# Error processing row 1196: 'Movie' object is not iterable
# Error processing row 1197: 'Movie' object is not iterable
# Error processing row 1198: 'Movie' object is not iterable
# Error processing row 1199: 'Movie' object is not iterable
# Error processing row 1200: 'Movie' object is not iterable
# Error processing row 1201: 'Movie' object is not iterable
# Error processing row 1202: 'Movie' object is not iterable
# Error processing row 1203: 'Movie' object is not iterable
# Error processing row 1204: 'Movie' object is not iterable
# Error processing row 1205: 'Movie' object is not iterable
# Error processing row 1206: 'Movie' object is not iterable
# Error processing row 1207: 'Movie' object is not iterable
# Error processing row 1208: 'Movie' object is not iterable
# Error processing row 1209: 'Movie' object is not iterable
# Error processing row 1210: 'Movie' object is not iterable
# Error processing row 1211: 'Movie' object is not iterable
# Error processing row 1212: 'Movie' object is not iterable
# Error processing row 1213: 'Movie' object is not iterable
# Error processing row 1214: 'Movie' object is not iterable
# Error processing row 1215: 'Movie' object is not iterable
# Error processing row 1216: 'Movie' object is not iterable
# Error processing row 1217: 'Movie' object is not iterable
# Error processing row 1218: 'Movie' object is not iterable
# Error processing row 1219: 'Movie' object is not iterable
# Error processing row 1220: 'Movie' object is not iterable
# Error processing row 1221: 'Movie' object is not iterable
# Error processing row 1222: 'Movie' object is not iterable
# Error processing row 1223: 'Movie' object is not iterable
# Error processing row 1224: 'Movie' object is not iterable
# Error processing row 1225: 'Movie' object is not iterable
# Error processing row 1226: 'Movie' object is not iterable
# Error processing row 1227: 'Movie' object is not iterable
# Error processing row 1228: 'Movie' object is not iterable
# Error processing row 1229: 'Movie' object is not iterable
# Error processing row 1230: 'Movie' object is not iterable
# Error processing row 1231: 'Movie' object is not iterable
# Error processing row 1232: 'Movie' object is not iterable
# Error processing row 1233: 'Movie' object is not iterable
# Error processing row 1234: 'Movie' object is not iterable
# Error processing row 1235: 'Movie' object is not iterable
# Error processing row 1236: 'Movie' object is not iterable
# Error processing row 1237: 'Movie' object is not iterable
# Error processing row 1238: 'Movie' object is not iterable
# Error processing row 1239: 'Movie' object is not iterable
# Error processing row 1240: 'Movie' object is not iterable
# Error processing row 1241: 'Movie' object is not iterable
# Error processing row 1242: 'Movie' object is not iterable
# Error processing row 1243: 'Movie' object is not iterable
# Error processing row 1244: 'Movie' object is not iterable
# Error processing row 1245: 'Movie' object is not iterable
# Error processing row 1246: 'Movie' object is not iterable
# Error processing row 1247: 'Movie' object is not iterable
# Error processing row 1248: 'Movie' object is not iterable
# Error processing row 1249: 'Movie' object is not iterable
# Error processing row 1250: 'Movie' object is not iterable
# Error processing row 1251: 'Movie' object is not iterable
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 21
#       4     movie = models.Movie(
#       5         title=row['title'],
#       6         overview=row['overview'],
#    (...)
#      18         Star4=row['Star4']
#      19     )
#      20     session.add(movie)
# ---> 21     session.commit()
#      23 #FOR ASSOCIATION RELATIONSHIP TABLES
#      24     # Link Genres
#      25     for genre_name in clean_and_split(row['genres_list']):
#
# File c:\Users\user\Desktop\UOW\Internet and Web Development\Assignment\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2028, in Session.commit(self)
#    2025 if trans is None:
#    2026     trans = self._autobegin_t()
# -> 2028 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File c:\Users\user\Desktop\UOW\Internet and Web Development\Assignment\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File c:\Users\user\Desktop\UOW\Internet and Web Development\Assignment\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1325, in SessionTransaction.commit(self, _to_root)
#    1322     self._state = SessionTransactionState.COMMITTED
#    1323     self.session.dispatch.after_commit(self.session)
# -> 1325     self._remove_snapshot()
#    1327 with self._expect_state(SessionTransactionState.CLOSED):
#    1328     self.close()
#
# File c:\Users\user\Desktop\UOW\Internet and Web Development\Assignment\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1138, in SessionTransaction._remove_snapshot(self)
#    1136 if not self.nested and self.session.expire_on_commit:
#    1137     for s in self.session.identity_map.all_states():
# -> 1138         s._expire(s.dict, self.session.identity_map._modified)
#    1140     statelib.InstanceState._detach_states(
#    1141         list(self._deleted), self.session
#    1142     )
#    1143     self._deleted.clear()
#
# File c:\Users\user\Desktop\UOW\Internet and Web Development\Assignment\.venv\Lib\site-packages\sqlalchemy\orm\state.py:746, in InstanceState._expire(self, dict_, modified_set)
#     741 if self._last_known_values:
#     742     self._last_known_values.update(
#     743         {k: dict_[k] for k in self._last_known_values if k in dict_}
#     744     )
# --> 746 for key in self.manager._all_key_set.intersection(dict_):
#     747     del dict_[key]
#     749 self.manager.dispatch.expire(self, None)
#
# KeyboardInterrupt:
