# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine
import pymysql
from os import environ
from dotenv import load_dotenv
from flask_sqlalchemy import SQLAlchemy
from flask import Flask
import sys
sys.path.append('Website')  # Add the Website directory to the system path

# Ensure the models module is installed
# %pip install -e Website

# Import your models
from models import Movie, Genre, Actor, Director, MovieGenre, MovieActor, MovieDirector, User

# Ensure tables are defined with extend_existing=True
Genre.__table__.extend_existing = True
Actor.__table__.extend_existing = True
Director.__table__.extend_existing = True
Movie.__table__.extend_existing = True
MovieGenre.__table__.extend_existing = True
MovieActor.__table__.extend_existing = True
MovieDirector.__table__.extend_existing = True
User.__table__.extend_existing = True
# Out:
# Obtaining file:///D:/Documents/IWD%20Assignment/Assignment/Website
# Note: you may need to restart the kernel to use updated packages.
# ERROR: file:///D:/Documents/IWD%20Assignment/Assignment/Website does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %% [markdown]
# **Helper Functions**

# %%
# Load environment variables from .env file
load_dotenv()

# Define the clean_and_split function
def clean_and_split(input_string):
    if pd.isna(input_string):
        return []
    return [item.strip() for item in input_string.replace('[', '').replace(']', '').replace("'", "").replace("\"", "").split(',')]

# Define the insert_unique_records function
# Define the insert_unique_records function
def insert_unique_records(session, model, items):
    unique_items = set(items)
    existing_items = {item.name for item in session.query(model).all()}
    new_items = unique_items - existing_items
    for item_name in new_items:
        try:
            session.add(model(name=item_name.strip()))
            session.commit()
        except Exception as e:
            session.rollback()
            print(f"Error inserting {item_name}: {e}")

# Define the create_database_if_not_exists function
def create_database_if_not_exists():
    # Load environment variables from .env file
    load_dotenv()
    connection = pymysql.connect(
        host=environ.get("DB_HOST"),
        user=environ.get("DB_USER"),
        password=environ.get("DB_PASSWORD")
    )
    cursor = connection.cursor()
    cursor.execute(f"CREATE DATABASE IF NOT EXISTS moviedb")
    cursor.close()
    connection.close()

# Create the database if it does not exist
create_database_if_not_exists()

# Create a new Flask app and SQLAlchemy instance
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] = environ.get('DATABASE_URI')
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
db = SQLAlchemy(app)

# %%
# Create the necessary tables if they do not exist
with app.app_context():
    db.create_all()

# Create a new session

engine = create_engine('mysql+pymysql://root:password@localhost:3306/moviedb')  # Replace with your actual database URI
Session = sessionmaker(bind=engine)
session = Session()

# %%
#Load CSV file 
movies_df = pd.read_csv("IMDb_Dataset_Edited.csv")
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89538 entries, 0 to 89537
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       89538 non-null  int64
#  1   title                    89538 non-null  object
#  2   vote_average             89538 non-null  float64
#  3   vote_count               89538 non-null  int64
#  4   status                   89538 non-null  object
#  5   release_date             89538 non-null  object
#  6   revenue                  89538 non-null  int64
#  7   runtime                  89538 non-null  int64
#  8   adult                    89538 non-null  bool
#  9   budget                   89538 non-null  int64
#  10  imdb_id                  40169 non-null  object
#  11  original_language        89538 non-null  object
#  12  original_title           89538 non-null  object
#  13  overview                 85545 non-null  object
#  14  popularity               89538 non-null  float64
#  15  tagline                  21199 non-null  object
#  16  production_companies     39255 non-null  object
#  17  production_countries     43045 non-null  object
#  18  spoken_languages         45698 non-null  object
#  19  keywords                 89538 non-null  object
#  20  release_year             89538 non-null  int64
#  21  Director                 89538 non-null  object
#  22  AverageRating            1118 non-null   float64
#  23  Poster_Link              174 non-null    object
#  24  Certificate              2566 non-null   object
#  25  IMDB_Rating              2596 non-null   float64
#  26  Meta_score               145 non-null    float64
#  27  Star1                    2596 non-null   object
#  28  Star2                    174 non-null    object
#  29  Star3                    174 non-null    object
#  30  Star4                    174 non-null    object
#  31  Writer                   53758 non-null  object
#  32  Director_of_Photography  27886 non-null  object
#  33  Producers                35010 non-null  object
#  34  Music_Composer           12716 non-null  object
#  35  genres_list              89538 non-null  object
#  36  Cast_list                89538 non-null  object
#  37  overview_sentiment       89538 non-null  float64
#  38  all_combined_keywords    89538 non-null  object
# dtypes: bool(1), float64(6), int64(6), object(26)
# memory usage: 26.0+ MB

# %% [markdown]
# 1. Insert Genres and Actors (for deduplication)

# %%
# Replace NaN values with None
movies_df = movies_df.where(pd.notnull(movies_df), None)


# # Insert Genres
# unique_genres = set(genre.strip() for genres in movies_df['genres_list'] if pd.notna(genres) for genre in genres.replace('[', '').replace(']', '').replace("'", "").split(', '))
# for genre_name in unique_genres:
#     genre = models.Genre(name=genre_name.strip())
#     session.add(genre)
# session.commit()

# # Clean and insert Actors
# unique_actors = set(actor.strip() for cast_list in movies_df['Cast_list'] if pd.notna(cast_list) for actor in cast_list.replace('[', '').replace(']', '').replace("'", "").split(', '))
# for actor_name in unique_actors:
#     actor = models.Actor(name=actor_name.strip())
#     session.add(actor)
# session.commit()


# # Insert Directors
# unique_directors = set(director.strip() for directors in movies_df['Director'] if pd.notna(directors) for director in directors.split(','))
# for director_name in unique_directors:
#     director = models.Director(name=director_name)
#     session.add(director)
# session.commit()

# Prepare data for genres, actors, and directors
genres = [genre for genres in movies_df['genres_list'] for genre in clean_and_split(genres)]
actors = [actor for cast_list in movies_df['Cast_list'] for actor in clean_and_split(cast_list)]
directors = [director for director_list in movies_df['Director'] for director in clean_and_split(director_list)]

movie_genres = [(row['title'], genre) for index, row in movies_df.iterrows() for genre in clean_and_split(row['genres_list'])]
movie_actors = [(row['title'], actor) for index, row in movies_df.iterrows() for actor in clean_and_split(row['Cast_list'])]
movie_directors = [(row['title'], director) for index, row in movies_df.iterrows() for director in clean_and_split(row['Director'])]

# Insert unique records for each model
insert_unique_records(session, Genre, genres)
insert_unique_records(session, Actor, actors)
insert_unique_records(session, Director, directors)

# After inserting unique genres, actors, and directors, the code retrieves all entries and creates dictionaries (genre_map, actor_map, director_map) 
# These dictionaries allow quick lookups for each genre, actor, or director without querying the database for each row to improve performance
genre_map = {g.name: g for g in session.query(Genre).all()}
actor_map = {a.name: a for a in session.query(Actor).all()}
director_map = {d.name: d for d in session.query(Director).all()}
movie_map = {m.title: m for m in session.query(Movie).all()}
# Out:
# Error inserting joseph talluto: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'joseph talluto' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'joseph talluto'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Daniel de Jonghe: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Daniel de Jonghe' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Daniel de Jonghe'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Rafael Alvarez: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Rafael Alvarez' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Rafael Alvarez'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Wang Qian-yuan: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Wang Qian-yuan' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Wang Qian-yuan'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting James Macdonald: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'James Macdonald' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'James Macdonald'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ahmed: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ahmed' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ahmed'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Almen Wong Pui-ha: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Almen Wong Pui-ha' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Almen Wong Pui-ha'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Laura: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Laura' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Laura'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ricardo AlÃ­s: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ricardo AlÃ\xads' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ricardo AlÃ\xads'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Kim Mi-Hye: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Kim Mi-Hye' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Kim Mi-Hye'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Lo Ta-Yu: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Lo Ta-Yu' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Lo Ta-Yu'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting jared martin: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'jared martin' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'jared martin'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ãxel Ricco: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ã\x81xel Ricco' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ã\x81xel Ricco'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Shauna Macdonald: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Shauna Macdonald' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Shauna Macdonald'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Kim Yong-woon: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Kim Yong-woon' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Kim Yong-woon'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Koray Karaca: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Koray Karaca' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Koray Karaca'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting JOHN CHOI: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'JOHN CHOI' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'JOHN CHOI'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Katherine WIlson: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Katherine WIlson' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Katherine WIlson'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Angel Ortiz: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Angel Ortiz' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Angel Ortiz'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Chin Siu-ho: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Chin Siu-ho' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Chin Siu-ho'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Yama: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Yama' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Yama'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting SEAN Young: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'SEAN Young' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'SEAN Young'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Alex Hafner: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Alex Hafner' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Alex Hafner'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Kim Ha-rim: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Kim Ha-rim' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Kim Ha-rim'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Rio: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Rio' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Rio'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Moon Hee-ra: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Moon Hee-ra' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Moon Hee-ra'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Lee Seul-gi: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Lee Seul-gi' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Lee Seul-gi'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ivan murphy: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ivan murphy' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ivan murphy'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Paul Smith: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Paul Smith' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Paul Smith'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Habiba: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Habiba' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Habiba'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting mark: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'mark' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'mark'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting maura stephens: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'maura stephens' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'maura stephens'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting amnon wolf: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'amnon wolf' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'amnon wolf'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Alex Castillo: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Alex Castillo' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Alex Castillo'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Alvaro Escobar: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Alvaro Escobar' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Alvaro Escobar'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Maged ElMasry: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Maged ElMasry' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Maged ElMasry'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting JosÃ© Alvarez: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'JosÃ© Alvarez' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'JosÃ© Alvarez'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting John MacKay: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'John MacKay' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'John MacKay'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Lee Lik-Chi: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Lee Lik-Chi' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Lee Lik-Chi'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Nirmal kumar: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Nirmal kumar' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Nirmal kumar'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Salvador Alvarez: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Salvador Alvarez' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Salvador Alvarez'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting jill brown: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'jill brown' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'jill brown'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Mazlan Pet pet: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Mazlan Pet pet' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Mazlan Pet pet'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Kim Young-min: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Kim Young-min' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Kim Young-min'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting JocÃ©nilde Gusmao SodrÃ©: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'JocÃ©nilde Gusmao SodrÃ©' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'JocÃ©nilde Gusmao SodrÃ©'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting DalÃ­: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'DalÃ\xad' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'DalÃ\xad'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Robert le BÃ©al: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Robert le BÃ©al' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Robert le BÃ©al'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting SABU: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'SABU' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'SABU'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ian Macdonald: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ian Macdonald' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ian Macdonald'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Bangen Ali: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Bangen Ali' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Bangen Ali'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Laura Avila: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Laura Avila' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Laura Avila'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting robert dean: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'robert dean' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'robert dean'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Dylan: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Dylan' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Dylan'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting John MacDonald: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'John MacDonald' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'John MacDonald'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Cindy Yip Sin-yi: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Cindy Yip Sin-yi' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Cindy Yip Sin-yi'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Saemapetch fairtex: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Saemapetch fairtex' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Saemapetch fairtex'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Kim Mi-Sun: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Kim Mi-Sun' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Kim Mi-Sun'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ramu: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ramu' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ramu'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting abdullah karakoyun: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'abdullah karakoyun' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'abdullah karakoyun'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Jr: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Jr' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Jr'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ku Kuan-chung: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ku Kuan-chung' for key 'actors.name'")
# [SQL: INSERT INTO actors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ku Kuan-chung'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Beatrice Pucci: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Beatrice Pucci' for key 'directors.name'")
# [SQL: INSERT INTO directors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Beatrice Pucci'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting ian adams: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'ian adams' for key 'directors.name'")
# [SQL: INSERT INTO directors (name) VALUES (%(name)s)]
# [parameters: {'name': 'ian adams'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Park Chan-wook: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Park Chan-wook' for key 'directors.name'")
# [SQL: INSERT INTO directors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Park Chan-wook'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Wei LI: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Wei LI' for key 'directors.name'")
# [SQL: INSERT INTO directors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Wei LI'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Ag Rojas: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Ag Rojas' for key 'directors.name'")
# [SQL: INSERT INTO directors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Ag Rojas'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# Error inserting Demarcus Bailey: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'Demarcus Bailey' for key 'directors.name'")
# [SQL: INSERT INTO directors (name) VALUES (%(name)s)]
# [parameters: {'name': 'Demarcus Bailey'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# 2. Insert Movies and link relationship

# %%
# Insert Movies and link relationships
movies_to_insert = []
for index, row in movies_df.iterrows():
    try:
        movie = Movie(
            title=row['title'],
            overview=row['overview'],
            status=row['status'],
            release_year=row['release_year'],
            popularity=row['popularity'],
            vote_average=row['vote_average'],
            vote_count=row['vote_count'],
            adult=row['adult'],
            overview_sentiment=row['overview_sentiment'],
            all_combined_keywords=row['all_combined_keywords'],
            Star1=row['Star1'],
            Star2=row['Star2'],
            Star3=row['Star3'],
            Star4=row['Star4']
        )
        movies_to_insert.append(movie)
        session.add(movie)  # Add the movie to the session
    except Exception as e:
        print(f"Error processing row {index}: {e}")

# Bulk insert movies
session.bulk_save_objects(movies_to_insert)
session.commit()

# Link relationships in bulk
for movie in movies_to_insert:
    try:
    #FOR ASSOCIATION RELATIONSHIP TABLES 
        # Link Genres
        for genre_name in clean_and_split(row['genres_list']):
            genre = genre_map.get(genre_name)
            if genre:
                movie.genres.append(genre)

        # Link Actors
        for actor_name in clean_and_split(row['Cast_list']):
            actor = actor_map.get(actor_name)
            if actor:
                movie.actors.append(actor)

        # Link Directors
        for director_name in clean_and_split(row['Director']):
            director = director_map.get(director_name)
            if director:
                movie.directors.append(director)
    except Exception as e:
        print(f"Error linking relationships for movie {movie.title}: {e}")

# Commit the relationships
session.commit()

# Insert movie_genres, movie_actors, and movie_directors relationships
for movie_title, genre_name in movie_genres:
    try:
        movie = movie_map.get(movie_title)
        genre = genre_map.get(genre_name)
        if movie and genre:
            session.add(MovieGenre(movie_id=movie.movie_id, genre_id=genre.genre_id))
    except Exception as e:
        print(f"Error linking movie {movie_title} with genre {genre_name}: {e}")

for movie_title, actor_name in movie_actors:
    try:
        movie = movie_map.get(movie_title)
        actor = actor_map.get(actor_name)
        if movie and actor:
            session.add(MovieActor(movie_id=movie.movie_id, actor_id=actor.actor_id))
    except Exception as e:
        print(f"Error linking movie {movie_title} with actor {actor_name}: {e}")

for movie_title, director_name in movie_directors:
    try:
        movie = movie_map.get(movie_title)
        director = director_map.get(director_name)
        if movie and director:
            session.add(MovieDirector(movie_id=movie.movie_id, director_id=director.director_id))
    except Exception as e:
        print(f"Error linking movie {movie_title} with director {director_name}: {e}")

# Commit the relationships
session.commit()

# Close the session
session.close()
